# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

df = pd.read_csv("Task (1) Dataset.csv")
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df = df.dropna(subset="Educational_level")
df = df.dropna(subset="Vehicle_driver_relation")
df = df.dropna(subset="Driving_experience")
df = df.dropna(subset="Type_of_vehicle")
df = df.dropna(subset="Owner_of_vehicle")

# I looked at samples and I noticed that there were a lot of fills with other values that are not null, so i decided to fill the gaps accordingly.
df["Service_year_of_vehicle"] = df["Service_year_of_vehicle"].fillna("Unknown")
df["Defect_of_vehicle"] = df["Defect_of_vehicle"].fillna("Unknown")
df["Area_accident_occured"] = df["Area_accident_occured"].fillna("Other")
df["Lanes_or_Medians"] = df["Lanes_or_Medians"].fillna("other")
df = df.dropna(subset="Road_allignment")
df["Types_of_Junction"] = df["Types_of_Junction"].fillna("Other")
df = df.dropna(subset="Road_surface_type")
df = df.dropna(subset="Type_of_collision")
df = df.dropna(subset="Vehicle_movement")
df["Work_of_casuality"] = df["Work_of_casuality"].fillna("Other")
df["Fitness_of_casuality"] = df["Fitness_of_casuality"].fillna("Normal")

df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  9451.000000           9451.000000
# mean                      2.038832              1.545657
# std                       0.689509              1.005438
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
#df["Time"] = pd.to_datetime(df["Time"], format='%h)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9451 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         9451 non-null   object
#  1   Day_of_week                  9451 non-null   object
#  2   Age_band_of_driver           9451 non-null   object
#  3   Sex_of_driver                9451 non-null   object
#  4   Educational_level            9451 non-null   object
#  5   Vehicle_driver_relation      9451 non-null   object
#  6   Driving_experience           9451 non-null   object
#  7   Type_of_vehicle              9451 non-null   object
#  8   Owner_of_vehicle             9451 non-null   object
#  9   Service_year_of_vehicle      9451 non-null   object
#  10  Defect_of_vehicle            9451 non-null   object
#  11  Area_accident_occured        9451 non-null   object
#  12  Lanes_or_Medians             9451 non-null   object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
print(df.describe())
print(df.corr)
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  9451.000000           9451.000000
# mean                      2.038832              1.545657
# std                       0.689509              1.005438
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000
# <bound method DataFrame.corr of            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.barplot(data=df, x='Day_of_week', y='Number_of_casualties')
# Out:
# <Axes: xlabel='Day_of_week', ylabel='Number_of_casualties'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.boxplot(data=df, x="Accident_severity",y="Age_band_of_driver")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Age_band_of_driver'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.pairplot(df)

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.boxenplot(data=df, x="Accident_severity",y="Sex_of_driver")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Sex_of_driver'>

# %%
sns.boxenplot(data=df, x="Accident_severity",y="Weather_conditions")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Weather_conditions'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# We can say that according to the data, the number of castualities on Sundays and Saturdays are higher than average

# Also, people with an age above 51 years old tend to have the least amount of fatal injuries, but they have the highest
# chances to have a slight injury

# We can say that in normal-raining weather conditions it is more likely when people get injured by an accident
# they end up with a slight to serious injuries
